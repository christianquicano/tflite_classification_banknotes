# %% [markdown]
# # Custom TransferLearning using EfficientNetB7

# %%
#!pip install keras

# %%
import tensorflow as tf

from tensorflow.keras.applications import EfficientNetB7
from tensorflow.keras.callbacks import ReduceLROnPlateau

from tensorflow_examples.lite.model_maker.core.data_util.image_dataloader import ImageClassifierDataLoader

import matplotlib.pyplot as plt
import numpy as np

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# # Carga de los datos para el entrenamiento

# %%
img_size = 300
batch_size = 32
path_train = 'data_' + str(img_size) + '/train'
path_test_validation = 'data_' + str(img_size) + '/validation'

# %%
datagen_train = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)
datagen_val = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

train_generator = datagen_train.flow_from_directory(
    path_train,
    target_size=(img_size, img_size),
    batch_size=batch_size)

val_generator = datagen_val.flow_from_directory(
    path_test_validation,
    target_size=(img_size, img_size),
    batch_size=batch_size)
# Out:
# Found 11972 images belonging to 5 classes.
# Found 1515 images belonging to 5 classes.

# %% [markdown]
# ## Mostrando los labels que van a ser entrenados

# %%
for image_batch, label_batch in train_generator:
  break
image_batch.shape, label_batch.shape

labels = '\n'.join(sorted(train_generator.class_indices.keys()))
print(labels)
# Out:
# 10
# 100
# 20
# 200
# 50

# %%
# numero de clases a entrenar
num_classes = len(train_generator.class_indices.keys())

# %%
base_model = EfficientNetB7(
    include_top=False,
    weights='imagenet',
    input_shape=(img_size,img_size,3)
)

# %%
base_model.trainable = False

# %%
base_model.summary()
# Out:
# Model: "efficientnetb7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 300, 300, 3) 0
# __________________________________________________________________________________________________
# rescaling (Rescaling)           (None, 300, 300, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# normalization (Normalization)   (None, 300, 300, 3)  7           rescaling[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 301, 301, 3)  0           normalization[0][0]
# __________________________________________________________________________________________________
# stem_conv (Conv2D)              (None, 150, 150, 64) 1728        stem_conv_pad[0][0]
# __________________________________________________________________________________________________
# stem_bn (BatchNormalization)    (None, 150, 150, 64) 256         stem_conv[0][0]
# __________________________________________________________________________________________________
# stem_activation (Activation)    (None, 150, 150, 64) 0           stem_bn[0][0]
# __________________________________________________________________________________________________
# block1a_dwconv (DepthwiseConv2D (None, 150, 150, 64) 576         stem_activation[0][0]
# __________________________________________________________________________________________________
# block1a_bn (BatchNormalization) (None, 150, 150, 64) 256         block1a_dwconv[0][0]
# __________________________________________________________________________________________________
# block1a_activation (Activation) (None, 150, 150, 64) 0           block1a_bn[0][0]
# __________________________________________________________________________________________________
# block1a_se_squeeze (GlobalAvera (None, 64)           0           block1a_activation[0][0]
# __________________________________________________________________________________________________
# block1a_se_reshape (Reshape)    (None, 1, 1, 64)     0           block1a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1a_se_reduce (Conv2D)      (None, 1, 1, 16)     1040        block1a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1a_se_expand (Conv2D)      (None, 1, 1, 64)     1088        block1a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1a_se_excite (Multiply)    (None, 150, 150, 64) 0           block1a_activation[0][0]
#                                                                  block1a_se_expand[0][0]
# __________________________________________________________________________________________________
# block1a_project_conv (Conv2D)   (None, 150, 150, 32) 2048        block1a_se_excite[0][0]
# __________________________________________________________________________________________________
# block1a_project_bn (BatchNormal (None, 150, 150, 32) 128         block1a_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_dwconv (DepthwiseConv2D (None, 150, 150, 32) 288         block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_bn (BatchNormalization) (None, 150, 150, 32) 128         block1b_dwconv[0][0]
# __________________________________________________________________________________________________
# block1b_activation (Activation) (None, 150, 150, 32) 0           block1b_bn[0][0]
# __________________________________________________________________________________________________
# block1b_se_squeeze (GlobalAvera (None, 32)           0           block1b_activation[0][0]
# __________________________________________________________________________________________________
# block1b_se_reshape (Reshape)    (None, 1, 1, 32)     0           block1b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1b_se_reduce (Conv2D)      (None, 1, 1, 8)      264         block1b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1b_se_expand (Conv2D)      (None, 1, 1, 32)     288         block1b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1b_se_excite (Multiply)    (None, 150, 150, 32) 0           block1b_activation[0][0]
#                                                                  block1b_se_expand[0][0]
# __________________________________________________________________________________________________
# block1b_project_conv (Conv2D)   (None, 150, 150, 32) 1024        block1b_se_excite[0][0]
# __________________________________________________________________________________________________
# block1b_project_bn (BatchNormal (None, 150, 150, 32) 128         block1b_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_drop (Dropout)          (None, 150, 150, 32) 0           block1b_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_add (Add)               (None, 150, 150, 32) 0           block1b_drop[0][0]
#                                                                  block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block1c_dwconv (DepthwiseConv2D (None, 150, 150, 32) 288         block1b_add[0][0]
# __________________________________________________________________________________________________
# block1c_bn (BatchNormalization) (None, 150, 150, 32) 128         block1c_dwconv[0][0]
# __________________________________________________________________________________________________
# block1c_activation (Activation) (None, 150, 150, 32) 0           block1c_bn[0][0]
# __________________________________________________________________________________________________
# block1c_se_squeeze (GlobalAvera (None, 32)           0           block1c_activation[0][0]
# __________________________________________________________________________________________________
# block1c_se_reshape (Reshape)    (None, 1, 1, 32)     0           block1c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1c_se_reduce (Conv2D)      (None, 1, 1, 8)      264         block1c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1c_se_expand (Conv2D)      (None, 1, 1, 32)     288         block1c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1c_se_excite (Multiply)    (None, 150, 150, 32) 0           block1c_activation[0][0]
#                                                                  block1c_se_expand[0][0]
# __________________________________________________________________________________________________
# block1c_project_conv (Conv2D)   (None, 150, 150, 32) 1024        block1c_se_excite[0][0]
# __________________________________________________________________________________________________
# block1c_project_bn (BatchNormal (None, 150, 150, 32) 128         block1c_project_conv[0][0]
# __________________________________________________________________________________________________
# block1c_drop (Dropout)          (None, 150, 150, 32) 0           block1c_project_bn[0][0]
# __________________________________________________________________________________________________
# block1c_add (Add)               (None, 150, 150, 32) 0           block1c_drop[0][0]
#                                                                  block1b_add[0][0]
# __________________________________________________________________________________________________
# block1d_dwconv (DepthwiseConv2D (None, 150, 150, 32) 288         block1c_add[0][0]
# __________________________________________________________________________________________________
# block1d_bn (BatchNormalization) (None, 150, 150, 32) 128         block1d_dwconv[0][0]
# __________________________________________________________________________________________________
# block1d_activation (Activation) (None, 150, 150, 32) 0           block1d_bn[0][0]
# __________________________________________________________________________________________________
# block1d_se_squeeze (GlobalAvera (None, 32)           0           block1d_activation[0][0]
# __________________________________________________________________________________________________
# block1d_se_reshape (Reshape)    (None, 1, 1, 32)     0           block1d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1d_se_reduce (Conv2D)      (None, 1, 1, 8)      264         block1d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1d_se_expand (Conv2D)      (None, 1, 1, 32)     288         block1d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1d_se_excite (Multiply)    (None, 150, 150, 32) 0           block1d_activation[0][0]
#                                                                  block1d_se_expand[0][0]
# __________________________________________________________________________________________________
# block1d_project_conv (Conv2D)   (None, 150, 150, 32) 1024        block1d_se_excite[0][0]
# __________________________________________________________________________________________________
# block1d_project_bn (BatchNormal (None, 150, 150, 32) 128         block1d_project_conv[0][0]
# __________________________________________________________________________________________________
# block1d_drop (Dropout)          (None, 150, 150, 32) 0           block1d_project_bn[0][0]
# __________________________________________________________________________________________________
# block1d_add (Add)               (None, 150, 150, 32) 0           block1d_drop[0][0]
#                                                                  block1c_add[0][0]
# __________________________________________________________________________________________________
# block2a_expand_conv (Conv2D)    (None, 150, 150, 192 6144        block1d_add[0][0]
# __________________________________________________________________________________________________
# block2a_expand_bn (BatchNormali (None, 150, 150, 192 768         block2a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2a_expand_activation (Acti (None, 150, 150, 192 0           block2a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv_pad (ZeroPadding (None, 151, 151, 192 0           block2a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv (DepthwiseConv2D (None, 75, 75, 192)  1728        block2a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block2a_bn (BatchNormalization) (None, 75, 75, 192)  768         block2a_dwconv[0][0]
# __________________________________________________________________________________________________
# block2a_activation (Activation) (None, 75, 75, 192)  0           block2a_bn[0][0]
# __________________________________________________________________________________________________
# block2a_se_squeeze (GlobalAvera (None, 192)          0           block2a_activation[0][0]
# __________________________________________________________________________________________________
# block2a_se_reshape (Reshape)    (None, 1, 1, 192)    0           block2a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2a_se_reduce (Conv2D)      (None, 1, 1, 8)      1544        block2a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2a_se_expand (Conv2D)      (None, 1, 1, 192)    1728        block2a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2a_se_excite (Multiply)    (None, 75, 75, 192)  0           block2a_activation[0][0]
#                                                                  block2a_se_expand[0][0]
# __________________________________________________________________________________________________
# block2a_project_conv (Conv2D)   (None, 75, 75, 48)   9216        block2a_se_excite[0][0]
# __________________________________________________________________________________________________
# block2a_project_bn (BatchNormal (None, 75, 75, 48)   192         block2a_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_conv (Conv2D)    (None, 75, 75, 288)  13824       block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_expand_bn (BatchNormali (None, 75, 75, 288)  1152        block2b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_activation (Acti (None, 75, 75, 288)  0           block2b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2b_dwconv (DepthwiseConv2D (None, 75, 75, 288)  2592        block2b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2b_bn (BatchNormalization) (None, 75, 75, 288)  1152        block2b_dwconv[0][0]
# __________________________________________________________________________________________________
# block2b_activation (Activation) (None, 75, 75, 288)  0           block2b_bn[0][0]
# __________________________________________________________________________________________________
# block2b_se_squeeze (GlobalAvera (None, 288)          0           block2b_activation[0][0]
# __________________________________________________________________________________________________
# block2b_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2b_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2b_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2b_se_excite (Multiply)    (None, 75, 75, 288)  0           block2b_activation[0][0]
#                                                                  block2b_se_expand[0][0]
# __________________________________________________________________________________________________
# block2b_project_conv (Conv2D)   (None, 75, 75, 48)   13824       block2b_se_excite[0][0]
# __________________________________________________________________________________________________
# block2b_project_bn (BatchNormal (None, 75, 75, 48)   192         block2b_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_drop (Dropout)          (None, 75, 75, 48)   0           block2b_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_add (Add)               (None, 75, 75, 48)   0           block2b_drop[0][0]
#                                                                  block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_expand_conv (Conv2D)    (None, 75, 75, 288)  13824       block2b_add[0][0]
# __________________________________________________________________________________________________
# block2c_expand_bn (BatchNormali (None, 75, 75, 288)  1152        block2c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2c_expand_activation (Acti (None, 75, 75, 288)  0           block2c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2c_dwconv (DepthwiseConv2D (None, 75, 75, 288)  2592        block2c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2c_bn (BatchNormalization) (None, 75, 75, 288)  1152        block2c_dwconv[0][0]
# __________________________________________________________________________________________________
# block2c_activation (Activation) (None, 75, 75, 288)  0           block2c_bn[0][0]
# __________________________________________________________________________________________________
# block2c_se_squeeze (GlobalAvera (None, 288)          0           block2c_activation[0][0]
# __________________________________________________________________________________________________
# block2c_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2c_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2c_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2c_se_excite (Multiply)    (None, 75, 75, 288)  0           block2c_activation[0][0]
#                                                                  block2c_se_expand[0][0]
# __________________________________________________________________________________________________
# block2c_project_conv (Conv2D)   (None, 75, 75, 48)   13824       block2c_se_excite[0][0]
# __________________________________________________________________________________________________
# block2c_project_bn (BatchNormal (None, 75, 75, 48)   192         block2c_project_conv[0][0]
# __________________________________________________________________________________________________
# block2c_drop (Dropout)          (None, 75, 75, 48)   0           block2c_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_add (Add)               (None, 75, 75, 48)   0           block2c_drop[0][0]
#                                                                  block2b_add[0][0]
# __________________________________________________________________________________________________
# block2d_expand_conv (Conv2D)    (None, 75, 75, 288)  13824       block2c_add[0][0]
# __________________________________________________________________________________________________
# block2d_expand_bn (BatchNormali (None, 75, 75, 288)  1152        block2d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2d_expand_activation (Acti (None, 75, 75, 288)  0           block2d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2d_dwconv (DepthwiseConv2D (None, 75, 75, 288)  2592        block2d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2d_bn (BatchNormalization) (None, 75, 75, 288)  1152        block2d_dwconv[0][0]
# __________________________________________________________________________________________________
# block2d_activation (Activation) (None, 75, 75, 288)  0           block2d_bn[0][0]
# __________________________________________________________________________________________________
# block2d_se_squeeze (GlobalAvera (None, 288)          0           block2d_activation[0][0]
# __________________________________________________________________________________________________
# block2d_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2d_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2d_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2d_se_excite (Multiply)    (None, 75, 75, 288)  0           block2d_activation[0][0]
#                                                                  block2d_se_expand[0][0]
# __________________________________________________________________________________________________
# block2d_project_conv (Conv2D)   (None, 75, 75, 48)   13824       block2d_se_excite[0][0]
# __________________________________________________________________________________________________
# block2d_project_bn (BatchNormal (None, 75, 75, 48)   192         block2d_project_conv[0][0]
# __________________________________________________________________________________________________
# block2d_drop (Dropout)          (None, 75, 75, 48)   0           block2d_project_bn[0][0]
# __________________________________________________________________________________________________
# block2d_add (Add)               (None, 75, 75, 48)   0           block2d_drop[0][0]
#                                                                  block2c_add[0][0]
# __________________________________________________________________________________________________
# block2e_expand_conv (Conv2D)    (None, 75, 75, 288)  13824       block2d_add[0][0]
# __________________________________________________________________________________________________
# block2e_expand_bn (BatchNormali (None, 75, 75, 288)  1152        block2e_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2e_expand_activation (Acti (None, 75, 75, 288)  0           block2e_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2e_dwconv (DepthwiseConv2D (None, 75, 75, 288)  2592        block2e_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2e_bn (BatchNormalization) (None, 75, 75, 288)  1152        block2e_dwconv[0][0]
# __________________________________________________________________________________________________
# block2e_activation (Activation) (None, 75, 75, 288)  0           block2e_bn[0][0]
# __________________________________________________________________________________________________
# block2e_se_squeeze (GlobalAvera (None, 288)          0           block2e_activation[0][0]
# __________________________________________________________________________________________________
# block2e_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2e_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2e_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2e_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2e_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2e_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2e_se_excite (Multiply)    (None, 75, 75, 288)  0           block2e_activation[0][0]
#                                                                  block2e_se_expand[0][0]
# __________________________________________________________________________________________________
# block2e_project_conv (Conv2D)   (None, 75, 75, 48)   13824       block2e_se_excite[0][0]
# __________________________________________________________________________________________________
# block2e_project_bn (BatchNormal (None, 75, 75, 48)   192         block2e_project_conv[0][0]
# __________________________________________________________________________________________________
# block2e_drop (Dropout)          (None, 75, 75, 48)   0           block2e_project_bn[0][0]
# __________________________________________________________________________________________________
# block2e_add (Add)               (None, 75, 75, 48)   0           block2e_drop[0][0]
#                                                                  block2d_add[0][0]
# __________________________________________________________________________________________________
# block2f_expand_conv (Conv2D)    (None, 75, 75, 288)  13824       block2e_add[0][0]
# __________________________________________________________________________________________________
# block2f_expand_bn (BatchNormali (None, 75, 75, 288)  1152        block2f_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2f_expand_activation (Acti (None, 75, 75, 288)  0           block2f_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2f_dwconv (DepthwiseConv2D (None, 75, 75, 288)  2592        block2f_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2f_bn (BatchNormalization) (None, 75, 75, 288)  1152        block2f_dwconv[0][0]
# __________________________________________________________________________________________________
# block2f_activation (Activation) (None, 75, 75, 288)  0           block2f_bn[0][0]
# __________________________________________________________________________________________________
# block2f_se_squeeze (GlobalAvera (None, 288)          0           block2f_activation[0][0]
# __________________________________________________________________________________________________
# block2f_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2f_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2f_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2f_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2f_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2f_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2f_se_excite (Multiply)    (None, 75, 75, 288)  0           block2f_activation[0][0]
#                                                                  block2f_se_expand[0][0]
# __________________________________________________________________________________________________
# block2f_project_conv (Conv2D)   (None, 75, 75, 48)   13824       block2f_se_excite[0][0]
# __________________________________________________________________________________________________
# block2f_project_bn (BatchNormal (None, 75, 75, 48)   192         block2f_project_conv[0][0]
# __________________________________________________________________________________________________
# block2f_drop (Dropout)          (None, 75, 75, 48)   0           block2f_project_bn[0][0]
# __________________________________________________________________________________________________
# block2f_add (Add)               (None, 75, 75, 48)   0           block2f_drop[0][0]
#                                                                  block2e_add[0][0]
# __________________________________________________________________________________________________
# block2g_expand_conv (Conv2D)    (None, 75, 75, 288)  13824       block2f_add[0][0]
# __________________________________________________________________________________________________
# block2g_expand_bn (BatchNormali (None, 75, 75, 288)  1152        block2g_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2g_expand_activation (Acti (None, 75, 75, 288)  0           block2g_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2g_dwconv (DepthwiseConv2D (None, 75, 75, 288)  2592        block2g_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2g_bn (BatchNormalization) (None, 75, 75, 288)  1152        block2g_dwconv[0][0]
# __________________________________________________________________________________________________
# block2g_activation (Activation) (None, 75, 75, 288)  0           block2g_bn[0][0]
# __________________________________________________________________________________________________
# block2g_se_squeeze (GlobalAvera (None, 288)          0           block2g_activation[0][0]
# __________________________________________________________________________________________________
# block2g_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2g_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2g_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2g_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2g_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2g_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2g_se_excite (Multiply)    (None, 75, 75, 288)  0           block2g_activation[0][0]
#                                                                  block2g_se_expand[0][0]
# __________________________________________________________________________________________________
# block2g_project_conv (Conv2D)   (None, 75, 75, 48)   13824       block2g_se_excite[0][0]
# __________________________________________________________________________________________________
# block2g_project_bn (BatchNormal (None, 75, 75, 48)   192         block2g_project_conv[0][0]
# __________________________________________________________________________________________________
# block2g_drop (Dropout)          (None, 75, 75, 48)   0           block2g_project_bn[0][0]
# __________________________________________________________________________________________________
# block2g_add (Add)               (None, 75, 75, 48)   0           block2g_drop[0][0]
#                                                                  block2f_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_conv (Conv2D)    (None, 75, 75, 288)  13824       block2g_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_bn (BatchNormali (None, 75, 75, 288)  1152        block3a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3a_expand_activation (Acti (None, 75, 75, 288)  0           block3a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv_pad (ZeroPadding (None, 79, 79, 288)  0           block3a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv (DepthwiseConv2D (None, 38, 38, 288)  7200        block3a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block3a_bn (BatchNormalization) (None, 38, 38, 288)  1152        block3a_dwconv[0][0]
# __________________________________________________________________________________________________
# block3a_activation (Activation) (None, 38, 38, 288)  0           block3a_bn[0][0]
# __________________________________________________________________________________________________
# block3a_se_squeeze (GlobalAvera (None, 288)          0           block3a_activation[0][0]
# __________________________________________________________________________________________________
# block3a_se_reshape (Reshape)    (None, 1, 1, 288)    0           block3a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3a_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block3a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3a_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block3a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3a_se_excite (Multiply)    (None, 38, 38, 288)  0           block3a_activation[0][0]
#                                                                  block3a_se_expand[0][0]
# __________________________________________________________________________________________________
# block3a_project_conv (Conv2D)   (None, 38, 38, 80)   23040       block3a_se_excite[0][0]
# __________________________________________________________________________________________________
# block3a_project_bn (BatchNormal (None, 38, 38, 80)   320         block3a_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_conv (Conv2D)    (None, 38, 38, 480)  38400       block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_expand_bn (BatchNormali (None, 38, 38, 480)  1920        block3b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_activation (Acti (None, 38, 38, 480)  0           block3b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3b_dwconv (DepthwiseConv2D (None, 38, 38, 480)  12000       block3b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3b_bn (BatchNormalization) (None, 38, 38, 480)  1920        block3b_dwconv[0][0]
# __________________________________________________________________________________________________
# block3b_activation (Activation) (None, 38, 38, 480)  0           block3b_bn[0][0]
# __________________________________________________________________________________________________
# block3b_se_squeeze (GlobalAvera (None, 480)          0           block3b_activation[0][0]
# __________________________________________________________________________________________________
# block3b_se_reshape (Reshape)    (None, 1, 1, 480)    0           block3b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3b_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block3b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3b_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block3b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3b_se_excite (Multiply)    (None, 38, 38, 480)  0           block3b_activation[0][0]
#                                                                  block3b_se_expand[0][0]
# __________________________________________________________________________________________________
# block3b_project_conv (Conv2D)   (None, 38, 38, 80)   38400       block3b_se_excite[0][0]
# __________________________________________________________________________________________________
# block3b_project_bn (BatchNormal (None, 38, 38, 80)   320         block3b_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_drop (Dropout)          (None, 38, 38, 80)   0           block3b_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_add (Add)               (None, 38, 38, 80)   0           block3b_drop[0][0]
#                                                                  block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_expand_conv (Conv2D)    (None, 38, 38, 480)  38400       block3b_add[0][0]
# __________________________________________________________________________________________________
# block3c_expand_bn (BatchNormali (None, 38, 38, 480)  1920        block3c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3c_expand_activation (Acti (None, 38, 38, 480)  0           block3c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3c_dwconv (DepthwiseConv2D (None, 38, 38, 480)  12000       block3c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3c_bn (BatchNormalization) (None, 38, 38, 480)  1920        block3c_dwconv[0][0]
# __________________________________________________________________________________________________
# block3c_activation (Activation) (None, 38, 38, 480)  0           block3c_bn[0][0]
# __________________________________________________________________________________________________
# block3c_se_squeeze (GlobalAvera (None, 480)          0           block3c_activation[0][0]
# __________________________________________________________________________________________________
# block3c_se_reshape (Reshape)    (None, 1, 1, 480)    0           block3c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3c_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block3c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3c_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block3c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3c_se_excite (Multiply)    (None, 38, 38, 480)  0           block3c_activation[0][0]
#                                                                  block3c_se_expand[0][0]
# __________________________________________________________________________________________________
# block3c_project_conv (Conv2D)   (None, 38, 38, 80)   38400       block3c_se_excite[0][0]
# __________________________________________________________________________________________________
# block3c_project_bn (BatchNormal (None, 38, 38, 80)   320         block3c_project_conv[0][0]
# __________________________________________________________________________________________________
# block3c_drop (Dropout)          (None, 38, 38, 80)   0           block3c_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_add (Add)               (None, 38, 38, 80)   0           block3c_drop[0][0]
#                                                                  block3b_add[0][0]
# __________________________________________________________________________________________________
# block3d_expand_conv (Conv2D)    (None, 38, 38, 480)  38400       block3c_add[0][0]
# __________________________________________________________________________________________________
# block3d_expand_bn (BatchNormali (None, 38, 38, 480)  1920        block3d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3d_expand_activation (Acti (None, 38, 38, 480)  0           block3d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3d_dwconv (DepthwiseConv2D (None, 38, 38, 480)  12000       block3d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3d_bn (BatchNormalization) (None, 38, 38, 480)  1920        block3d_dwconv[0][0]
# __________________________________________________________________________________________________
# block3d_activation (Activation) (None, 38, 38, 480)  0           block3d_bn[0][0]
# __________________________________________________________________________________________________
# block3d_se_squeeze (GlobalAvera (None, 480)          0           block3d_activation[0][0]
# __________________________________________________________________________________________________
# block3d_se_reshape (Reshape)    (None, 1, 1, 480)    0           block3d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3d_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block3d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3d_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block3d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3d_se_excite (Multiply)    (None, 38, 38, 480)  0           block3d_activation[0][0]
#                                                                  block3d_se_expand[0][0]
# __________________________________________________________________________________________________
# block3d_project_conv (Conv2D)   (None, 38, 38, 80)   38400       block3d_se_excite[0][0]
# __________________________________________________________________________________________________
# block3d_project_bn (BatchNormal (None, 38, 38, 80)   320         block3d_project_conv[0][0]
# __________________________________________________________________________________________________
# block3d_drop (Dropout)          (None, 38, 38, 80)   0           block3d_project_bn[0][0]
# __________________________________________________________________________________________________
# block3d_add (Add)               (None, 38, 38, 80)   0           block3d_drop[0][0]
#                                                                  block3c_add[0][0]
# __________________________________________________________________________________________________
# block3e_expand_conv (Conv2D)    (None, 38, 38, 480)  38400       block3d_add[0][0]
# __________________________________________________________________________________________________
# block3e_expand_bn (BatchNormali (None, 38, 38, 480)  1920        block3e_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3e_expand_activation (Acti (None, 38, 38, 480)  0           block3e_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3e_dwconv (DepthwiseConv2D (None, 38, 38, 480)  12000       block3e_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3e_bn (BatchNormalization) (None, 38, 38, 480)  1920        block3e_dwconv[0][0]
# __________________________________________________________________________________________________
# block3e_activation (Activation) (None, 38, 38, 480)  0           block3e_bn[0][0]
# __________________________________________________________________________________________________
# block3e_se_squeeze (GlobalAvera (None, 480)          0           block3e_activation[0][0]
# __________________________________________________________________________________________________
# block3e_se_reshape (Reshape)    (None, 1, 1, 480)    0           block3e_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3e_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block3e_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3e_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block3e_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3e_se_excite (Multiply)    (None, 38, 38, 480)  0           block3e_activation[0][0]
#                                                                  block3e_se_expand[0][0]
# ...
# block6m_expand_bn (BatchNormali (None, 10, 10, 2304) 9216        block6m_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6m_expand_activation (Acti (None, 10, 10, 2304) 0           block6m_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6m_dwconv (DepthwiseConv2D (None, 10, 10, 2304) 57600       block6m_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6m_bn (BatchNormalization) (None, 10, 10, 2304) 9216        block6m_dwconv[0][0]
# __________________________________________________________________________________________________
# block6m_activation (Activation) (None, 10, 10, 2304) 0           block6m_bn[0][0]
# __________________________________________________________________________________________________
# block6m_se_squeeze (GlobalAvera (None, 2304)         0           block6m_activation[0][0]
# __________________________________________________________________________________________________
# block6m_se_reshape (Reshape)    (None, 1, 1, 2304)   0           block6m_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6m_se_reduce (Conv2D)      (None, 1, 1, 96)     221280      block6m_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6m_se_expand (Conv2D)      (None, 1, 1, 2304)   223488      block6m_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6m_se_excite (Multiply)    (None, 10, 10, 2304) 0           block6m_activation[0][0]
#                                                                  block6m_se_expand[0][0]
# __________________________________________________________________________________________________
# block6m_project_conv (Conv2D)   (None, 10, 10, 384)  884736      block6m_se_excite[0][0]
# __________________________________________________________________________________________________
# block6m_project_bn (BatchNormal (None, 10, 10, 384)  1536        block6m_project_conv[0][0]
# __________________________________________________________________________________________________
# block6m_drop (Dropout)          (None, 10, 10, 384)  0           block6m_project_bn[0][0]
# __________________________________________________________________________________________________
# block6m_add (Add)               (None, 10, 10, 384)  0           block6m_drop[0][0]
#                                                                  block6l_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_conv (Conv2D)    (None, 10, 10, 2304) 884736      block6m_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_bn (BatchNormali (None, 10, 10, 2304) 9216        block7a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7a_expand_activation (Acti (None, 10, 10, 2304) 0           block7a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7a_dwconv (DepthwiseConv2D (None, 10, 10, 2304) 20736       block7a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7a_bn (BatchNormalization) (None, 10, 10, 2304) 9216        block7a_dwconv[0][0]
# __________________________________________________________________________________________________
# block7a_activation (Activation) (None, 10, 10, 2304) 0           block7a_bn[0][0]
# __________________________________________________________________________________________________
# block7a_se_squeeze (GlobalAvera (None, 2304)         0           block7a_activation[0][0]
# __________________________________________________________________________________________________
# block7a_se_reshape (Reshape)    (None, 1, 1, 2304)   0           block7a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7a_se_reduce (Conv2D)      (None, 1, 1, 96)     221280      block7a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7a_se_expand (Conv2D)      (None, 1, 1, 2304)   223488      block7a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7a_se_excite (Multiply)    (None, 10, 10, 2304) 0           block7a_activation[0][0]
#                                                                  block7a_se_expand[0][0]
# __________________________________________________________________________________________________
# block7a_project_conv (Conv2D)   (None, 10, 10, 640)  1474560     block7a_se_excite[0][0]
# __________________________________________________________________________________________________
# block7a_project_bn (BatchNormal (None, 10, 10, 640)  2560        block7a_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_conv (Conv2D)    (None, 10, 10, 3840) 2457600     block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_expand_bn (BatchNormali (None, 10, 10, 3840) 15360       block7b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_activation (Acti (None, 10, 10, 3840) 0           block7b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7b_dwconv (DepthwiseConv2D (None, 10, 10, 3840) 34560       block7b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7b_bn (BatchNormalization) (None, 10, 10, 3840) 15360       block7b_dwconv[0][0]
# __________________________________________________________________________________________________
# block7b_activation (Activation) (None, 10, 10, 3840) 0           block7b_bn[0][0]
# __________________________________________________________________________________________________
# block7b_se_squeeze (GlobalAvera (None, 3840)         0           block7b_activation[0][0]
# __________________________________________________________________________________________________
# block7b_se_reshape (Reshape)    (None, 1, 1, 3840)   0           block7b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7b_se_reduce (Conv2D)      (None, 1, 1, 160)    614560      block7b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7b_se_expand (Conv2D)      (None, 1, 1, 3840)   618240      block7b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7b_se_excite (Multiply)    (None, 10, 10, 3840) 0           block7b_activation[0][0]
#                                                                  block7b_se_expand[0][0]
# __________________________________________________________________________________________________
# block7b_project_conv (Conv2D)   (None, 10, 10, 640)  2457600     block7b_se_excite[0][0]
# __________________________________________________________________________________________________
# block7b_project_bn (BatchNormal (None, 10, 10, 640)  2560        block7b_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_drop (Dropout)          (None, 10, 10, 640)  0           block7b_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_add (Add)               (None, 10, 10, 640)  0           block7b_drop[0][0]
#                                                                  block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# block7c_expand_conv (Conv2D)    (None, 10, 10, 3840) 2457600     block7b_add[0][0]
# __________________________________________________________________________________________________
# block7c_expand_bn (BatchNormali (None, 10, 10, 3840) 15360       block7c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7c_expand_activation (Acti (None, 10, 10, 3840) 0           block7c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7c_dwconv (DepthwiseConv2D (None, 10, 10, 3840) 34560       block7c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7c_bn (BatchNormalization) (None, 10, 10, 3840) 15360       block7c_dwconv[0][0]
# __________________________________________________________________________________________________
# block7c_activation (Activation) (None, 10, 10, 3840) 0           block7c_bn[0][0]
# __________________________________________________________________________________________________
# block7c_se_squeeze (GlobalAvera (None, 3840)         0           block7c_activation[0][0]
# __________________________________________________________________________________________________
# block7c_se_reshape (Reshape)    (None, 1, 1, 3840)   0           block7c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7c_se_reduce (Conv2D)      (None, 1, 1, 160)    614560      block7c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7c_se_expand (Conv2D)      (None, 1, 1, 3840)   618240      block7c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7c_se_excite (Multiply)    (None, 10, 10, 3840) 0           block7c_activation[0][0]
#                                                                  block7c_se_expand[0][0]
# __________________________________________________________________________________________________
# block7c_project_conv (Conv2D)   (None, 10, 10, 640)  2457600     block7c_se_excite[0][0]
# __________________________________________________________________________________________________
# block7c_project_bn (BatchNormal (None, 10, 10, 640)  2560        block7c_project_conv[0][0]
# __________________________________________________________________________________________________
# block7c_drop (Dropout)          (None, 10, 10, 640)  0           block7c_project_bn[0][0]
# __________________________________________________________________________________________________
# block7c_add (Add)               (None, 10, 10, 640)  0           block7c_drop[0][0]
#                                                                  block7b_add[0][0]
# __________________________________________________________________________________________________
# block7d_expand_conv (Conv2D)    (None, 10, 10, 3840) 2457600     block7c_add[0][0]
# __________________________________________________________________________________________________
# block7d_expand_bn (BatchNormali (None, 10, 10, 3840) 15360       block7d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7d_expand_activation (Acti (None, 10, 10, 3840) 0           block7d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7d_dwconv (DepthwiseConv2D (None, 10, 10, 3840) 34560       block7d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7d_bn (BatchNormalization) (None, 10, 10, 3840) 15360       block7d_dwconv[0][0]
# __________________________________________________________________________________________________
# block7d_activation (Activation) (None, 10, 10, 3840) 0           block7d_bn[0][0]
# __________________________________________________________________________________________________
# block7d_se_squeeze (GlobalAvera (None, 3840)         0           block7d_activation[0][0]
# __________________________________________________________________________________________________
# block7d_se_reshape (Reshape)    (None, 1, 1, 3840)   0           block7d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7d_se_reduce (Conv2D)      (None, 1, 1, 160)    614560      block7d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7d_se_expand (Conv2D)      (None, 1, 1, 3840)   618240      block7d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7d_se_excite (Multiply)    (None, 10, 10, 3840) 0           block7d_activation[0][0]
#                                                                  block7d_se_expand[0][0]
# __________________________________________________________________________________________________
# block7d_project_conv (Conv2D)   (None, 10, 10, 640)  2457600     block7d_se_excite[0][0]
# __________________________________________________________________________________________________
# block7d_project_bn (BatchNormal (None, 10, 10, 640)  2560        block7d_project_conv[0][0]
# __________________________________________________________________________________________________
# block7d_drop (Dropout)          (None, 10, 10, 640)  0           block7d_project_bn[0][0]
# __________________________________________________________________________________________________
# block7d_add (Add)               (None, 10, 10, 640)  0           block7d_drop[0][0]
#                                                                  block7c_add[0][0]
# __________________________________________________________________________________________________
# top_conv (Conv2D)               (None, 10, 10, 2560) 1638400     block7d_add[0][0]
# __________________________________________________________________________________________________
# top_bn (BatchNormalization)     (None, 10, 10, 2560) 10240       top_conv[0][0]
# __________________________________________________________________________________________________
# top_activation (Activation)     (None, 10, 10, 2560) 0           top_bn[0][0]
# ==================================================================================================
# Total params: 64,097,687
# Trainable params: 0
# Non-trainable params: 64,097,687
# __________________________________________________________________________________________________

# %% [markdown]
# # Empezando el entrenamiento

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, BatchNormalization, GlobalAveragePooling2D

# %%
model = tf.keras.Sequential([
  base_model,
  Flatten(),
  Dense(32, activation='relu'),
  Dense(num_classes, activation='softmax')
])

# %% [markdown]
# ## Compilamos el modelo

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001) #default learning_rate = 0.001
loss = 'categorical_crossentropy'
metrics = ['accuracy']

model.compile(optimizer=optimizer, 
              loss=loss, 
              metrics=metrics)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# efficientnetb7 (Functional)  (None, 10, 10, 2560)      64097687
# _________________________________________________________________
# flatten (Flatten)            (None, 256000)            0
# _________________________________________________________________
# dense (Dense)                (None, 32)                8192032
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 165
# =================================================================
# Total params: 72,289,884
# Trainable params: 8,192,197
# Non-trainable params: 64,097,687
# _________________________________________________________________

# %%
epochs = 10
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=2, verbose=1,)
history = model.fit(train_generator, 
                    epochs=epochs,
                    callbacks=[reduce_lr],
                    verbose=1,
                    validation_data=val_generator)
# Out:
# Epoch 1/10
# 375/375 [==============================] - 181s 483ms/step - loss: 1.6960 - accuracy: 0.1996 - val_loss: 1.6094 - val_accuracy: 0.2013
# Epoch 2/10
# 375/375 [==============================] - 177s 472ms/step - loss: 1.6094 - accuracy: 0.1984 - val_loss: 1.6094 - val_accuracy: 0.2013
# Epoch 3/10
# 375/375 [==============================] - ETA: 0s - loss: 1.6095 - accuracy: 0.1969
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 375/375 [==============================] - 179s 478ms/step - loss: 1.6095 - accuracy: 0.1969 - val_loss: 1.6094 - val_accuracy: 0.1993
# Epoch 4/10
# 375/375 [==============================] - 181s 484ms/step - loss: 1.6094 - accuracy: 0.2005 - val_loss: 1.6094 - val_accuracy: 0.1993
# Epoch 5/10
#  12/375 [..............................] - ETA: 2:24 - loss: 1.6094 - accuracy: 0.2083
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-c4f76531dd78> in <module>
#       5                     callbacks=[reduce_lr],
#       6                     verbose=1,
# ----> 7                     validation_data=val_generator)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2815     with self._lock:
#    2816       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2817     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2818
#    2819   @property
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1840                            resource_variable_ops.BaseResourceVariable))],
#    1841         captured_inputs=self.captured_inputs,
# -> 1842         cancellation_manager=cancellation_manager)
#    1843
#    1844   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1916       # No tape is watching; skip to running the function.
#    1917       return self._build_call_outputs(self._inference_function.call(
# -> 1918           ctx, args, cancellation_manager=cancellation_manager))
#    1919     forward_backward = self._select_forward_and_backward_functions(
#    1920         args,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Creando un gráfico para la revisión

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
#plt.ylim([min(plt.ylim()),1])
plt.ylim([0,1.1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
#plt.ylim([0,1.0])
plt.ylim([0,20])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# ## Guardando el modelo

# %%
saved_model_dir = 'model_EfficientNetB7'
tf.saved_model.save(model, saved_model_dir)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: model_EfficientNetB7/assets

# %% [markdown]
# ## Convirtiendo el modelo en tensorflow lite para el uso en mobile

# %%
# Convert the model.
converter = tf.lite.TFLiteConverter.from_saved_model(saved_model_dir)
tflite_model = converter.convert()

path_tensorflow_lite = 'model_tflite/model_EfficientNetB7.tflite'
with open(path_tensorflow_lite, 'wb') as f:
  f.write(tflite_model)
# Out:
# WARNING:tensorflow:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_114418) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_179253) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5g_expand_activation_layer_call_and_return_conditional_losses_197222) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_108843) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5i_activation_layer_call_and_return_conditional_losses_107575) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block2f_se_reduce_layer_call_and_return_conditional_losses_95899) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_179646) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_109631) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_200079) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_97167) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_105422) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5h_activation_layer_call_and_return_conditional_losses_107135) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6j_se_reduce_layer_call_and_return_conditional_losses_112410) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5e_se_reduce_layer_call_and_return_conditional_losses_196295) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_109723) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block3d_expand_activation_layer_call_and_return_conditional_losses_186256) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5e_activation_layer_call_and_return_conditional_losses_105815) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4g_expand_activation_layer_call_and_return_conditional_losses_191739) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_201046) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block1c_activation_layer_call_and_return_conditional_losses_180006) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6l_se_reduce_layer_call_and_return_conditional_losses_113290) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_195189) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6k_expand_activation_layer_call_and_return_conditional_losses_112711) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_185150) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block3g_activation_layer_call_and_return_conditional_losses_99320) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_94139) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_181879) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6l_se_reduce_layer_call_and_return_conditional_losses_205649) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_94579) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_sequential_layer_call_and_return_conditional_losses_159022) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block3e_activation_layer_call_and_return_conditional_losses_186948) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_189527) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_105375) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_104403) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block3g_se_reduce_layer_call_and_return_conditional_losses_188094) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_96733) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4g_expand_activation_layer_call_and_return_conditional_losses_102256) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_108363) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_110163) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block2e_expand_activation_layer_call_and_return_conditional_losses_95320) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_201738) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block7c_se_reduce_layer_call_and_return_conditional_losses_114997) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block7c_se_reduce_layer_call_and_return_conditional_losses_207814) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block3e_expand_activation_layer_call_and_return_conditional_losses_186809) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6g_expand_activation_layer_call_and_return_conditional_losses_202705) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block3e_se_reduce_layer_call_and_return_conditional_losses_186988) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5i_se_reduce_layer_call_and_return_conditional_losses_107622) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_189113) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_94000) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4e_se_reduce_layer_call_and_return_conditional_losses_190812) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6i_expand_activation_layer_call_and_return_conditional_losses_203811) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_199940) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_194636) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4e_expand_activation_layer_call_and_return_conditional_losses_190633) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5h_expand_activation_layer_call_and_return_conditional_losses_197775) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_92600) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6l_expand_activation_layer_call_and_return_conditional_losses_113151) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block3d_se_reduce_layer_call_and_return_conditional_losses_98047) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block2f_activation_layer_call_and_return_conditional_losses_95852) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_104016) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_185329) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_182018) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_108890) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6i_expand_activation_layer_call_and_return_conditional_losses_111831) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6h_se_reduce_layer_call_and_return_conditional_losses_203437) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6h_activation_layer_call_and_return_conditional_losses_203397) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6k_se_reduce_layer_call_and_return_conditional_losses_112850) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block1c_activation_layer_call_and_return_conditional_losses_92932) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4f_expand_activation_layer_call_and_return_conditional_losses_101816) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_189706) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_109191) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_190080) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block3e_activation_layer_call_and_return_conditional_losses_98440) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5i_expand_activation_layer_call_and_return_conditional_losses_107483) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5i_expand_activation_layer_call_and_return_conditional_losses_198328) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block7b_se_reduce_layer_call_and_return_conditional_losses_207261) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6h_se_reduce_layer_call_and_return_conditional_losses_111530) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4h_activation_layer_call_and_return_conditional_losses_192431) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_184783) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4h_expand_activation_layer_call_and_return_conditional_losses_192292) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6g_activation_layer_call_and_return_conditional_losses_111043) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_190259) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_195702) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5j_activation_layer_call_and_return_conditional_losses_199020) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4e_expand_activation_layer_call_and_return_conditional_losses_101376) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6j_activation_layer_call_and_return_conditional_losses_112363) with ops with custom gradients. Will likely fail if a gradient is requested.
# ...
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb7_layer_call_and_return_conditional_losses_169330) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block7d_se_reduce_layer_call_and_return_conditional_losses_115437) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_100496) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6h_activation_layer_call_and_return_conditional_losses_111483) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6m_expand_activation_layer_call_and_return_conditional_losses_113591) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_104108) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block2e_activation_layer_call_and_return_conditional_losses_95412) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_195563) with ops with custom gradients. Will likely fail if a gradient is requested.

# %% [markdown]
# # Tomando 25 imágenes de validación y observando el resultado

# %%
test_data = ImageClassifierDataLoader.from_folder(path_test_validation)

def get_label_color(val1, val2):
  if val1 == val2:
    return 'black'
  else:
    return 'red'

plt.figure(figsize=(20, 20))

for i, (image, label) in enumerate(test_data.dataset.take(100)):
    ax = plt.subplot(10, 10, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(image.numpy(), cmap=plt.cm.gray)

    swapped = np.moveaxis(image, 0, 1)
    arr4d = np.expand_dims(swapped, 0)
    id_predict = np.argmax(model.predict(arr4d))
    
    predict_label = "100"
    if id_predict == 1:
        predict_label = "20"
    color = get_label_color(predict_label, test_data.index_to_label[label.numpy()])
    #color = 'black'
    ax.xaxis.label.set_color(color)
    plt.xlabel('Predicted: %s' % predict_label)
plt.show()
# Out:
# INFO:tensorflow:Load image with size: 1515, num_label: 5, labels: 10, 100, 20, 200, 50.
# INFO:tensorflow:Load image with size: 1515, num_label: 5, labels: 10, 100, 20, 200, 50.
